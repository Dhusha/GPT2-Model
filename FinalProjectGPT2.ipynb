# %%
# !pip3 install torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.18.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 36.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105

# %%
import torch
from torchtext.data.utils import get_tokenizer
from collections import Counter
from torchtext.vocab import build_vocab_from_iterator

# Sample text data
text = """GUVI, founded with the mission to democratize technical education, is an innovative edtech platform designed to offer high-quality, accessible online technology courses. The platform stands out by providing education in multiple native languages, making it easier for non-English speakers to learn coding and technology skills.
GUVI's mission is to bridge the gap between education and employment by offering affordable, quality education that is accessible to all. Their vision is to empower individuals from diverse backgrounds with the technical skills needed to succeed in the modern workforce. By removing language barriers and providing practical, hands-on learning experiences, GUVI aims to create a global community of skilled professionals.Zen Class is GUVI's flagship program that offers immersive, job-oriented training in various technology domains. The program is designed to provide hands-on experience and mentorship, ensuring that learners are job-ready upon completion.GUVI stands as a testament to the power of accessible and inclusive education. By providing high-quality technical education in native languages, GUVI is breaking down barriers and creating opportunities for learners worldwide. Whether through their comprehensive courses, interactive platforms like Codekata and Webkata, or innovative programs like Zen Class, GUVI is committed to empowering the next generation of tech professionals.
GUVI stands as a testament to the power of accessible and inclusive education. By providing high-quality technical education in native languages, GUVI is breaking down barriers and creating opportunities for learners worldwide. Whether through their comprehensive courses, interactive platforms like Codekata and Webkata, or innovative programs like Zen Class, GUVI is committed to empowering the next generation of tech professionals.
GUVI's innovative approach to education, combined with its focus on inclusivity and quality, has made it a significant player in the EdTech industry. By offering courses in multiple languages, providing hands-on learning experiences, and ensuring industry relevance, GUVI continues to empower learners and professionals to excel in the technology sector.
Codekata is an online platform within GUVI where learners can practice coding problems and improve their problem-solving skills. It offers a variety of challenges that range from beginner to advanced levels, helping students to:
Develop logical thinking and coding proficiency.
Prepare for coding interviews and competitive programming contests.
Gain practical experience through hands-on problem-solving."""

# Tokenize the text
tokenizer = get_tokenizer('basic_english')
tokens = tokenizer(text.lower())

# Build the vocabulary
counter = Counter(tokens)
vocab = build_vocab_from_iterator([tokens], specials=['<unk>', '<pad>'])
vocab.set_default_index(vocab['<unk>'])

# Numericalize the text
data = [vocab[token] for token in tokens]

# Convert data to tensors and create batches
seq_length = 30
def create_batches(data, seq_length):
    sequences = [data[i:i+seq_length] for i in range(0, len(data)-seq_length)]
    inputs = torch.tensor([seq[:-1] for seq in sequences], dtype=torch.long)
    targets = torch.tensor([seq[-1] for seq in sequences], dtype=torch.long)
    return inputs, targets

inputs, targets = create_batches(data, seq_length)
train_data, val_data = inputs[:int(0.8*len(inputs))], inputs[int(0.8*len(inputs)):]
train_targets, val_targets = targets[:int(0.8*len(targets))], targets[int(0.8*len(targets)):]

# DataLoader
train_dataset = torch.utils.data.TensorDataset(train_data, train_targets)
val_dataset = torch.utils.data.TensorDataset(val_data, val_targets)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=20, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=20)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchtext/data/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.10/dist-packages/torchtext/vocab/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.10/dist-packages/torchtext/utils.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)

# %%
import torch.nn as nn
import torch.optim as optim

class RNNModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super(RNNModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.RNN(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        embedded = self.embedding(x)
        output, hidden = self.rnn(embedded)
        output = self.fc(output[:, -1, :])
        return output

# Initialize the model, criterion, and optimizer
vocab_size = len(vocab)
embedding_dim = 100
hidden_dim = 100
output_dim = vocab_size

model = RNNModel(vocab_size, embedding_dim, hidden_dim, output_dim).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# %%
def train_epoch(loader, model, criterion, optimizer):
    model.train()
    total_loss = 0
    for inputs, targets in loader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        output = model(inputs)
        loss = criterion(output, targets)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def evaluate(loader, model, criterion):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for inputs, targets in loader:
            inputs, targets = inputs.to(device), targets.to(device)
            output = model(inputs)
            loss = criterion(output, targets)
            total_loss += loss.item()
    return total_loss / len(loader)

for epoch in range(1, 15):
    train_loss = train_epoch(train_loader, model, criterion, optimizer)
    val_loss = evaluate(val_loader, model, criterion)
    print(f'Epoch {epoch}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')
# Out:
# Epoch 1, Train Loss: 1.3737, Val Loss: 5.4773
# Epoch 2, Train Loss: 1.2230, Val Loss: 5.5310
# Epoch 3, Train Loss: 1.0421, Val Loss: 5.5547
# Epoch 4, Train Loss: 0.9228, Val Loss: 5.5912
# Epoch 5, Train Loss: 0.7977, Val Loss: 5.6246
# Epoch 6, Train Loss: 0.7423, Val Loss: 5.6617
# Epoch 7, Train Loss: 0.6910, Val Loss: 5.6655
# Epoch 8, Train Loss: 0.5697, Val Loss: 5.7181
# Epoch 9, Train Loss: 0.5146, Val Loss: 5.7437
# Epoch 10, Train Loss: 0.4490, Val Loss: 5.7695
# Epoch 11, Train Loss: 0.4023, Val Loss: 5.8267
# Epoch 12, Train Loss: 0.3772, Val Loss: 5.8349
# Epoch 13, Train Loss: 0.3277, Val Loss: 5.8572
# Epoch 14, Train Loss: 0.3022, Val Loss: 5.8813

# %%
def generate_text(model, seed_text, vocab, tokenizer, next_words=50, temperature=1.0):
    model.eval()
    tokens = tokenizer(seed_text.lower())
    input_ids = torch.tensor([vocab[token] for token in tokens], dtype=torch.long).unsqueeze(0).to(device)

    generated_text = seed_text
    with torch.no_grad():
        for _ in range(next_words):
            output = model(input_ids)
            output = output.squeeze(0)  # Remove the batch dimension
            output = output / temperature
            probabilities = torch.nn.functional.softmax(output, dim=-1)
            next_token_id = torch.multinomial(probabilities, num_samples=1).item()
            next_token = vocab.lookup_token(next_token_id)
            generated_text += ' ' + next_token
            next_input = torch.tensor([[next_token_id]], dtype=torch.long).to(device)
            input_ids = torch.cat((input_ids, next_input), dim=1)

    return generated_text

seed_text = "GUVI is"
generated_text = generate_text(model, seed_text, vocab, tokenizer, next_words=50, temperature=0.7)
print(generated_text)
# Out:
# GUVI is committed to empowering the next generation of tech professionals . guvi stands as a testament to the power of accessible and inclusive education . by providing high-quality technical education in native languages , guvi is breaking down barriers and creating opportunities for learners worldwide . whether through their comprehensive courses

# %%
class LSTMModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super(LSTMModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        embedded = self.embedding(x)
        output, (hidden, cell) = self.lstm(embedded)
        output = self.fc(output[:, -1, :])
        return output

# Initialize the LSTM model
model = LSTMModel(vocab_size, embedding_dim, hidden_dim, output_dim).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# Train the LSTM model
for epoch in range(1, 15):
    train_loss = train_epoch(train_loader, model, criterion, optimizer)
    val_loss = evaluate(val_loader, model, criterion)
    print(f'Epoch {epoch}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')
# Out:
# Epoch 1, Train Loss: 5.0773, Val Loss: 5.0792
# Epoch 2, Train Loss: 4.8770, Val Loss: 5.0834
# Epoch 3, Train Loss: 4.5805, Val Loss: 5.3581
# Epoch 4, Train Loss: 4.0731, Val Loss: 5.3802
# Epoch 5, Train Loss: 3.6619, Val Loss: 5.6114
# Epoch 6, Train Loss: 3.2762, Val Loss: 5.8233
# Epoch 7, Train Loss: 2.9726, Val Loss: 5.7074
# Epoch 8, Train Loss: 2.6050, Val Loss: 6.0344
# Epoch 9, Train Loss: 2.3269, Val Loss: 5.9016
# Epoch 10, Train Loss: 2.0446, Val Loss: 6.0791
# Epoch 11, Train Loss: 1.7882, Val Loss: 6.1225
# Epoch 12, Train Loss: 1.6151, Val Loss: 6.0641
# Epoch 13, Train Loss: 1.4262, Val Loss: 6.2762
# Epoch 14, Train Loss: 1.2739, Val Loss: 6.1950

# %%
def generate_text(model, seed_text, vocab, tokenizer, next_words=50, temperature=1.0):
    model.eval()
    tokens = tokenizer(seed_text.lower())
    input_ids = torch.tensor([vocab[token] for token in tokens], dtype=torch.long).unsqueeze(0).to(device)

    generated_text = seed_text
    with torch.no_grad():
        for _ in range(next_words):
            output = model(input_ids)
            output = output.squeeze(0)  # Remove the batch dimension
            output = output / temperature
            probabilities = torch.nn.functional.softmax(output, dim=-1)
            next_token_id = torch.multinomial(probabilities, num_samples=1).item()
            next_token = vocab.lookup_token(next_token_id)
            generated_text += ' ' + next_token
            next_input = torch.tensor([[next_token_id]], dtype=torch.long).to(device)
            input_ids = torch.cat((input_ids, next_input), dim=1)

    return generated_text

seed_text = "Codekata"
generated_text = generate_text(model, seed_text, vocab, tokenizer, next_words=50, temperature=1.0)
print(generated_text)
# Out:
# Codekata removing barriers and ensuring experiences job-ready webkata combined advanced community and s of class . providing hands-on learning on experiences testament , and platforms practical . , innovative learning a , to individuals empowering in experience multiple languages and providing hands-on languages , ensuring it quality hands-on s . whether

# %%
import torch.nn as nn
import torch.optim as optim
import math

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

class TransformerModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, nhead, num_encoder_layers, hidden_dim, output_dim):
        super(TransformerModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.pos_encoder = PositionalEncoding(embedding_dim)
        encoder_layers = nn.TransformerEncoderLayer(embedding_dim, nhead, hidden_dim)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_encoder_layers)
        self.fc = nn.Linear(embedding_dim, output_dim)

    def forward(self, x):
        embedded = self.embedding(x) * math.sqrt(embedding_dim)
        embedded = self.pos_encoder(embedded)
        output = self.transformer_encoder(embedded)
        output = self.fc(output[:, -1, :])
        return output

# Initialize the model, criterion, and optimizer
vocab_size = len(vocab)
embedding_dim = 200
nhead = 2
num_encoder_layers = 2
hidden_dim = 200
output_dim = vocab_size

model = TransformerModel(vocab_size, embedding_dim, nhead, num_encoder_layers, hidden_dim, output_dim).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
def train_epoch(loader, model, criterion, optimizer):
    model.train()
    total_loss = 0
    for inputs, targets in loader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        output = model(inputs)
        loss = criterion(output, targets)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def evaluate(loader, model, criterion):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for inputs, targets in loader:
            inputs, targets = inputs.to(device), targets.to(device)
            output = model(inputs)
            loss = criterion(output, targets)
            total_loss += loss.item()
    return total_loss / len(loader)

for epoch in range(1, 15):
    train_loss = train_epoch(train_loader, model, criterion, optimizer)
    val_loss = evaluate(val_loader, model, criterion)
    print(f'Epoch {epoch}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')
# Out:
# Epoch 1, Train Loss: 1.1442, Val Loss: 6.9056
# Epoch 2, Train Loss: 1.1858, Val Loss: 6.9694
# Epoch 3, Train Loss: 1.0719, Val Loss: 7.0800
# Epoch 4, Train Loss: 1.1453, Val Loss: 7.1768
# Epoch 5, Train Loss: 1.1096, Val Loss: 7.3371
# Epoch 6, Train Loss: 1.0951, Val Loss: 7.4274
# Epoch 7, Train Loss: 1.0772, Val Loss: 7.4718
# Epoch 8, Train Loss: 0.9924, Val Loss: 7.4860
# Epoch 9, Train Loss: 1.1151, Val Loss: 7.5202
# Epoch 10, Train Loss: 0.9903, Val Loss: 7.4964
# Epoch 11, Train Loss: 1.0484, Val Loss: 7.5559
# Epoch 12, Train Loss: 1.0425, Val Loss: 7.5296
# Epoch 13, Train Loss: 0.9883, Val Loss: 7.5312
# Epoch 14, Train Loss: 0.9743, Val Loss: 7.6489

# %%
def generate_text(model, seed_text, vocab, tokenizer, next_words=50, temperature=1.0):
    model.eval()
    tokens = tokenizer(seed_text.lower())
    input_ids = torch.tensor([vocab[token] for token in tokens], dtype=torch.long).unsqueeze(0).to(device)

    generated_text = seed_text
    with torch.no_grad():
        for _ in range(next_words):
            output = model(input_ids)
            output = output.squeeze(0)  # Remove the batch dimension
            output = output / temperature
            probabilities = torch.nn.functional.softmax(output, dim=-1)
            next_token_id = torch.multinomial(probabilities, num_samples=1).item()
            next_token = vocab.lookup_token(next_token_id)
            generated_text += ' ' + next_token
            next_input = torch.tensor([[next_token_id]], dtype=torch.long).to(device)
            input_ids = torch.cat((input_ids, next_input), dim=1)

    return generated_text

seed_text = "GUVI is"
generated_text = generate_text(model, seed_text, vocab, tokenizer, next_words=50, temperature=0.6)
print(generated_text)
# Out:
# GUVI is committed to empowering the next generation of tech professionals . whether through their comprehensive courses in the gap between education is breaking down barriers and inclusive education and inclusive education in multiple native languages , hands-on learning experiences , or innovative programs like zen class , ensuring that offers immersive

# %%
# !pip install -U transformers huggingface_hub
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Collecting transformers
#   Downloading transformers-4.42.2-py3-none-any.whl (9.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 40.0 MB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.23.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.3)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.2
#     Uninstalling transformers-4.41.2:
#       Successfully uninstalled transformers-4.41.2
# Successfully installed transformers-4.42.2

# %%
# !pip uninstall transformers -y
# !pip install transformers
# Out:
# Found existing installation: transformers 4.42.2
# Uninstalling transformers-4.42.2:
#   Successfully uninstalled transformers-4.42.2
# Collecting transformers
#   Using cached transformers-4.42.2-py3-none-any.whl (9.3 MB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# Installing collected packages: transformers
# Successfully installed transformers-4.42.2

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.23.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.15.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.6.2)

# %%
from huggingface_hub import login

login('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')
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("google/gemma-7b")
model = AutoModelForCausalLM.from_pretrained("google/gemma-7b")

input_text = "Write me a poem about Machine Learning."
input_ids = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(**input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/33.6k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/2.11G [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer

# Specify the model name or identifier
model_name = "gpt2"  # You can use other models like "gpt2-medium", "gpt2-large", "gpt2-xl", "gpt-neo-125M", etc.

# Load the pre-trained model and tokenizer
model = AutoModelForCausalLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Create a text generation pipeline
text_generator = pipeline("text-generation", model=model, tokenizer=tokenizer)

# Generate text
prompt = "GUVI"
generated_text = text_generator(prompt, max_length=100, do_sample=True, temperature=0.7)

print(generated_text[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# GUVIAN O'DONNELL,
#
# "I will be there," he cried. "I have just got a very good idea. One day I shall have this little boat in my hands."
#
# "I will," said Mrs. Macaulay, "but I shall take my time. I will wait for you."
#
# "How long it will take, I can't tell you. I've got to wait for it to grow on my son, and I can

# %%
pip install transformers datasets torch fastapi uvicorn
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.2)
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Collecting fastapi
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 3.4 MB/s eta 0:00:00
# Collecting uvicorn
#   Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests (from transformers)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.1 MB/s eta 0:00:00
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.7 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.40)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi) (2.7.4)
# Collecting fastapi-cli>=0.0.2 (from fastapi)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Collecting httpx>=0.23.0 (from fastapi)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.9 MB/s eta 0:00:00
# Collecting python-multipart>=0.0.7 (from fastapi)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.7 MB/s eta 0:00:00
# Collecting orjson>=3.2.1 (from fastapi)
#   Downloading orjson-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 5.1 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi)
#   Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (8.1.7)
# Collecting h11>=0.8 (from uvicorn)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.1 MB/s eta 0:00:00
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 23.3 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi) (3.7)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.10/dist-packages (from fastapi-cli>=0.0.2->fastapi) (0.12.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (2024.6.2)
# Collecting httpcore==1.* (from httpx>=0.23.0->fastapi)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Collecting httptools>=0.5.0 (from uvicorn)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 15.4 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 32.9 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.6 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.23.0->fastapi) (1.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (0.1.2)
# Installing collected packages: xxhash, websockets, uvloop, ujson, requests, python-multipart, python-dotenv, pyarrow, orjson, httptools, h11, dnspython, dill, watchfiles, uvicorn, starlette, multiprocess, httpcore, email_validator, httpx, fastapi-cli, datasets, fastapi
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 16.1.0 which is incompatible.
# Successfully installed datasets-2.20.0 dill-0.3.8 dnspython-2.6.1 email_validator-2.2.0 fastapi-0.111.0 fastapi-cli-0.0.4 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 multiprocess-0.70.16 orjson-3.10.5 pyarrow-16.1.0 python-dotenv-1.0.1 python-multipart-0.0.9 requests-2.32.3 starlette-0.37.2 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-12.0 xxhash-3.4.1

# %%
import os
import re
from transformers import GPT2Tokenizer

def print_raw_data(input_file):
    with open(input_file, 'r', encoding='utf-8') as f:
        for line in f:
            print(line.strip())

input_file = "/content/Guvi - Cleaned (2).txt"  # Your company-specific data file
print_raw_data(input_file)
# Out:
# ﻿About Guvi
#
#
# Guvi Geek Networks Private Limited, commonly known as GUVI, is an Indian technology company that focuses on providing skill development and training in various domains related to information technology and computer science. Here are some key details about GUVI:
#
#
# Founding and Background
# GUVI was founded with the mission of bridging the skill gap in the IT industry by offering practical, industry-relevant training.
# The company was established to cater to the growing demand for skilled professionals in emerging technologies like artificial intelligence, machine learning, data science, and programming.
#
#
# Educational Platform
# GUVI operates an online learning platform that offers courses, tutorials, and projects designed to enhance technical skills.
# It focuses on providing hands-on learning experiences through coding challenges, real-world projects, and interactive sessions.
#
#
# Courses and Content
# GUVI offers a wide range of courses covering programming languages such as Python, Java, C++, web development, mobile app development, data structures, algorithms, and more.
# The platform also provides specialized courses in advanced topics like artificial intelligence, machine learning, blockchain, and cybersecurity.
#
#
# Certifications and Partnerships
# GUVI provides certificates of completion for its courses, which can be valuable for showcasing skills to potential employers.
# The platform collaborates with industry experts and companies to develop and deliver content that meets industry standards and demands.
#
#
# Community and Support
# GUVI fosters a community of learners through forums, discussion boards, and collaborative projects.
# It offers mentorship and support to help learners navigate their educational journey and succeed in their career goals.
#
#
# Innovation and Impact
# GUVI emphasizes innovation in education technology, continuously updating its course offerings to align with industry trends and technological advancements.
# The platform aims to make quality technical education accessible to a global audience, promoting skill development and career advancement.
#
#
# Overall, GUVI Geek Networks Private Limited plays a significant role in the education sector by equipping learners with practical skills and knowledge necessary to thrive in the tech industry.
# The founder of GUVI (Guvi Geek Networks Private Limited) is Aravindhan Vivekanandan. He founded GUVI with the vision of democratizing technical education and making programming skills accessible to everyone, particularly focusing on students and professionals aspiring to build careers in the technology sector. Aravindhan Vivekanandan continues to lead GUVI in its mission to bridge the skill gap in the IT industry through practical, hands-on learning experiences and industry-relevant training courses.
#
#
# As of my last update, GUVI (Guvi Geek Networks Private Limited) is located in Chennai, India. They operate from their office in Chennai where they manage their online learning platform and conduct various educational programs aimed at skill development in IT and related fields.
#
#
# As of my last update, specific information regarding the exact number of employees working at GUVI Geek Networks Private Limited was not readily available. For the most accurate and current information on their workforce size, I recommend visiting GUVI's official website or contacting them directly through their official communication channels. Company websites often provide updates on their team size and organizational structure.
#
#
# As of my last update, GUVI offers a variety of courses across different domains of technology and programming. They cover a range of topics including programming languages such as Python, Java, C++, web development, mobile app development, data structures, algorithms, artificial intelligence, machine learning, blockchain, cybersecurity, and more.
#
#
# The exact number of courses available on GUVI's platform may vary over time as they update and add new content. For the most current and detailed information about their course offerings, including specific topics and availability, it's best to visit GUVI's official website or directly explore their course catalog.
#
#
# As of my last update, GUVI Geek Networks Private Limited primarily focuses on providing technical education and skill development through online courses and training programs. While they may offer career support and guidance, including assistance with resume building and interview preparation, specific details about "100% placement assistance" such as guaranteed job placements or partnerships with companies for placements were not prominently featured in their offerings.
#
#
# It's essential to note that placement assistance can vary widely among educational platforms and institutions. If you are considering GUVI for career advancement or job placement support, it would be beneficial to directly contact them or explore their website for the latest information on their placement services and support.
#
#
# GUVI (Guvi Geek Networks Private Limited) was founded in the year 2014. It was established with the aim of providing accessible and practical technical education through online courses and training programs, focusing on programming and IT skills development. Since its inception, GUVI has been working towards bridging the skill gap in the IT industry by offering industry-relevant learning experiences to students and professionals alike.
#
#
# As of my last update, specific information about "friend companies" or official partner companies of GUVI (Guvi Geek Networks Private Limited) was not publicly detailed. Typically, companies may have strategic partnerships or collaborations with other organizations in the tech industry, educational institutions, or corporate entities for various purposes such as content development, recruitment, or joint initiatives.
#
#
# For the most accurate and current information about GUVI's partnerships or affiliations with other companies, it is recommended to visit GUVI's official website or reach out to them directly through their official communication channels. They may provide insights into any formal collaborations or alliances they have established in the industry.
#
#
# GUVI - Zen Class Success Stories
# Tech deserves YOU! And Zen class prepares you to stand out from the crowd. With dedicated career guidance, exuberant career fairs, and hackathons ZEN makes you job-ready.
# With ZEN, you get to learn, practice a lot, and then get hired by the top tech companies like Google, Microsoft, Flipkart, Zoho, Freshworks, etc. Reviews on GUVI always mention about the excellent placement guidance that GUVI provides
#
#
# What students say about Guvi?
# Vishnu
# "The training process that has been followed in GUVI is so systematic and well programmed. The hands-on tasks are prepared so well. Mentors are so friendly and most talented and can answer any kind of doubt & available all the time throughout your course. My overall experience was so good and I thank GUVI again for helping me to get into the best company as a full stack developer."
# Siddarth: (FSD)
# "Even though I have completed BE mechanical engineering I underwent a three-month course on full-stack development at GUVI and this platform helped me in securing a developer job immediately with the best package. Thanks to the mentor and GUVI team"
#
#
# Why Zen Class is the Most Successful Bootcamp?
# Conducted by an IIT Madras incubated company, GUVI. ZEN is an all-in-one project-based Full-Stack Developer Bootcamp. It is one of the industry’s leading Full Stack Development Programs to master in-demand Tech skills from the Subject Matter Experts. ZEN assures Placement Guidance placing you in top companies with high salaries. This Full-stack Developer Program is specially curated to cover every related technology in-depth to help you become a successful Full-stack Developer.
#
#
# How to join ZEN CLass:
# Pre-Book
# By paying ₹5500/- (100% refundable) Just pay ₹5500/- as the first installment and pre-book your seat. You may pay the remaining amount as the second installment for BootCamp.
# Attend Pre-BootCamp JS Sessions(6 weekdays / 3 weekends)
# This is a preparatory BootCamp, wherein you will have rigorous coaching sessions which will make you ready for the actual BootCamp.
# Take JS Assessment
# This is an assessment to prove your eligibility and learning readiness. If you pass then Hurray! So, you get promoted to the next level. Upon failing, you will still receive the Refund of your Booking Fees.
# After Selection proceed to ZEN BootCamp
# You now stand eligible to receive a pass to Proceed to BootCamp. Just pay the remaining fees and Start Learning!
# Enquire about our course fee
#
#
# Here’s why to choose ZEN:  At GUVI, learners benefit from comprehensive placement guidance to enhance career prospects. The platform offers self-paced online classes across various domains, complemented by industry-relevant certificates upon completion. Learners enjoy unlimited access to a wealth of course resources and engage in real-world projects, building practical skills. Moreover, GUVI provides excellent mentor support, ensuring personalized guidance throughout the learning journey.
# CoursesLive Classes ZEN CLASS Live Online Classes, LIVE Online Intensive Program + Placement Guidance, IIT-M Pravartak Certified Full Stack Development Program (FSD) where you can learn Javascript, HTML, CSS, Java, Data Structure, MongoDB & more. Also, explore the IIT-M Pravartak Certified Data Science Program covering Python, Machine Learning, NLP, Tableau, PowerBI & more, and an Automation & Testing Program teaching Selenium, Python, Java, Jenkins, Jmeter, API Testing & more. Practice your skills through Codekata to sharpen coding and prepare for interviews, Webkata for basic Frontend and Backend development, and Debugging, a series curated by Industry Experts. Use IDE - Online Compiler to run & test code in any language. Resources include Learn Hub, New, Rewards, Referral, Forum Support, Blogs, App Download, and opportunities to Become an Affiliate.
# Our Products include HackerKid for K-12 children's coding classes, GUVI for Corporates to meet hiring & training needs, and Placement Preparation to ace your aptitude. Accredited by IIT-M & IIM-A, GUVI focuses on personalized learning solutions, offering online learning, upskilling, and recruitment opportunities in multiple languages. Recognized by ENTREPRENEUR INDIA and ZEE Digital, GUVI has set records for online programming lessons. Access over 175+ Premium Courses with new additions monthly, with Live Classes ensuring Guaranteed Job Placement Support and Hands-on Coding Experience.
#
#
# GUVI offers an interactive platform for programming practice with 1500+ coding problems curated by industry veterans. CodeKata tracks performance and builds coding profiles for showcasing skills in job recruitment. WebKata focuses on developing web development skills with tasks in HTML, CSS, and JavaScript, supporting advanced projects on GitHub. Debugging, curated by industry experts, helps programmers start and gain familiarity with coding, enhancing interview readiness. GUVI IDE is an Integrated Development Environment enabling code writing, editing, running, testing, and debugging in 20 programming languages. Users earn rewards through CodeKata, WebKata, and referrals, redeemable for various rewards like iPhones and Amazon vouchers. The forum serves as a technical community platform for discussing tech doubts and news, with expert responses within 48 hours.
# GUVI, an IIT-M & IIM-A incubated Ed-tech company, offers personalized learning solutions including online learning, upskilling, and recruitment opportunities, emphasizing tech skills in native languages. Their Zen Class and live online programs cover diverse courses from programming languages to data science, UI/UX principles, and automation tools. For corporate needs, GUVI provides tailored training, fresher hiring, and end-to-end campus hiring solutions. Their approach focuses on practical skill development and job placement support, evidenced by learner success stories in securing IT roles.
# GUVI, 72% of learners successfully complete their courses within just 3 months, demonstrating their rapid progress. Moreover, 78% of learners exhibit accelerated retention of concepts, while 84% demonstrate enhanced comprehension of complex topics, showcasing the platform's effective educational impact.
# GUVI offers courses in English, Tamil, Hindi, Malayalam, Kannada, Telugu, and Bengali, training to a diverse learner base of over 3,027,862 individuals. The platform boasts 194 mentors who guide students through their learning journey. Participants have collectively submitted 36,577,214 lines of code, reflecting active engagement in practical coding exercises. Additionally, GUVI enriches learning with 1,673 educational videos across various topics and languages.An interactive platform for programming practice with 1500+ coding problems curated by the best programming veterans in the IT industry. CodeKata tracks the performance develops coding profile for the coders to showcase their skillset in job recruitment process. Boost up your potential to crack coding interviews by solving CodeKata problems. WebKata is the developing practice platform for beginners, built with top-notch web development problem statements focusing on Modern HTML, CSS JavaScript. Further, advanced projects can be developed onGitHub. Accelerate your Web Development skills through WebKata assignments. Debugging a series of programs curated by experts from the industry. Practising on Debugging will help you get started and be familiarised with programming. We will recommend your profile to recruiting companies based on your performance in debugging. You can be a better programmer and crack interviews by completing Debugging. GUVI IDE is an Integrated Development Environment that lets you write, edit, run, test debug your code. You can fix your code with the debugger supported by language like JavaScript, Python3 Ruby. While, you can write code in 20 different programming languages. Rewards are for GUVI users to redeem the points earned through CodeKata, WebKata, through Referral. Exciting rewards can be earned just by referring GUVI to family, friends others. Referral scheme of GUVI is as simple as a click. Share the referral code with your peers, family friends to earn points and further, redeem those points for unbelievable rewards like iPhone, Amazon Vouchers, etc. Forum is technical community platform for students, professionals, or any tech-geek to discuss the latest technical doubts, software upgradations or any trending tech news. Our dedicated tech-experts will address all the tech-queries within 48hrs. An interactive platform for programming practice with 1500+ coding problems curated by the best programming veterans in the IT industry. CodeKata tracks the performance develops coding profile for the coders to showcase their skillset in job recruitment process. Boost up your potential to crack coding interviews by solving CodeKata problems. Learn Javascript, HTML, CSS more Learn Python, NLP, Tableau more Learn UI, UX Principles more Learn Selenium, Python, Java more Want to become our Hiring Partner? CorporateTraning Suite Hire TrainedFreshers LateralHiring HYREassessment End-to-EndCampus Hiring Learners Mentors Lines of Code Submission Videos of Learners complete their courses within 3 months of Learners could recollect the concepts faster of Learners have better understanding over complex topics And We love them! Reviews The Best Part of the ZEN course is Placements I wanted to make a career shift to IT, attended weekend batch of ZEN course, every week we had assignments, this helped me alot the best part is placements. I almost attended 10 companies for the interview got selected in 3 companies, I took up offer from product based company, currently Im working as Software Developer in iQuanti India Pvt.Ltd Software Developer Subscribe to our newsletter for alerts on New Courses, Free Workshops, Masterclasses. Zen Class LIVE CLASS Popular Courses Self-Paced Courses Practice Platforms Products Resources Company Zen Class LIVE CLASS Popular Courses Self-Paced Courses Practice Platforms Products Resources Company Zen Class LIVE CLASS Company Popular Courses Self-Paced Courses Practice Platforms Resources For Universities For School Children For Intervi ...
# Programming Languages Data Science Network and Security Web Development IT and Softwares Database and Cloud Computing Software Testing and Automation Artificial Intelligence
# Complete your profile to make it visible to the recruiters
# CODEKATA CodeKata is a series of programs curated by the veterans in IT Software industry. It hosts coding problems asked by top MNCs like Microsoft, Walmart, Samsung so on. Practising on Codekata will take your coding skills to the next level. We will recommend your profile to recruiting companies based on your performance in Codekata. Search Become a Premium member by purchasing our courses Free Membership
# Codekata - Limited Access MicroARC - Limited Access Premium Membership Codekata - Unlimited Access MicroARC - Unlimited Access Go to Courses Get complete access Buy any Premium course to get access to 1000+ questions of Codekata and Webkata Explore Courses
# WebKata Learn Web development skills by a series of tasks. Webkata is the Front-end practice platform which hosts tasks on Web Development skills like HTML, CSS, and Javascript. This cloud-based module enables you to practice Front-end skills without needing to set up a local environment.
# Become a Premium member by purchasing our courses Free Membership Codekata - Limited Access MicroArc - Limited Access Premium Membership Codekata - Unlimited Access MicroArc - Unlimited Access
# Upgrade to PRO To get access to 500+ Skill Assessment questions in Webkata 1000+ Problems in Codekata 1000+ Skill Assessment in Microarc And many more PRO benefits... Upgrade to Pro
# Debugging Debugging a series of programs curated by experts from the industry. Practising to debug a program will help you get better at programming. We will recommend your profile to recruiting companies based on your performance in debugging. You can be a proficient programmer & gain the potential to crack coding interviews by practising on this debugging platform.
# Rewards Watch course videos, complete course activities, & solve problems in CodeKata, WebKata, Debugging & IDE to collect geekoins & redeem to win exciting rewards.
# Empty Here, But Don't Lose Hope! Your First Reward is Just Around the Corner! Get My Reward Run Count: In CodeKata, You can use Run Counts to compile your code and verify the test cases before submitting the source code.
# No Search Results Found! No topics or articles in our library match the keyword you entered. Please try any other relevant keyword for better results.
# Hurray! Redeemed All Rewards! You have redeemed all the rewards here. Do look out this space for more exciting rewards that are coming soon.
# How It Works Earn Geekoins by completing activities in courses and solving problems in CodeKata, WebKata, Debugging and IDE. Use the earned Geekoins to redeem rewards from your favourite brands. Enjoy these exciting offers and discounts before they expire.
# Frequently Asked Questions
# * How will I receive the earned rewards? Once you redeem using your earned Geekoins, you will get a coupon code which you can use to avail the offer.
# * In case of Run Counts, Your claimed Run Counts will be added to the total Run Counts in CodeKata.
# * How to earn Geekoins? Watch the course videos, complete the activities, assignments & problems in CodeKata, WebKata, IDE and you will earn Geekoins accordingly. Claim Now!
# Do you want to use Geekoins to claim the reward? Yaay! Run Counts Added. Run counts have been added to your Codekata.
# Apple Air Pods To complete your claim, Please fill the given form: Full Name Mobile Number Address (Flat/Door No./Building/Apartment/Company) City/District/Town Pincode State Country Landmark(optional) Alternate Mobile Number(optional) *Our Customer success team will get in touch with you in 24 hours and You will receive your Premium reward in one week.
# Refer & Earn Great Rewards. Apple products, Amazon Voucher & much more to win! It's a win-win season. Refer GUVI Free industry accredited courses to your friends & family to win exciting rewards. Earn referral points upon each verified sign-up & redeem points later to claim your prize. More Signups = Bigger Rewards!
# How does it work? Login to start referring your friends! Login to Refer Referral Link Referral Code Copy
# Share in Login to Refer
# How can Everybody Win Rewards? How will I win Rewards upon Referral? Refer GUVI's AI for India Program 2.0 to your friends, & when they sign-up to GUVI for enrolling to this event, then Your referral sign-up count increases. You'd win multiple amazing gifts like Amazon Gift Vouchers, Discount coupons & GUVI premium passes based on your referral sign-up count.
# How does this benefit my Friends? Your friends can sign-up to GUVI's AI for India Program 2.0 and get amazing opportunity to participate in India's largest virtual AI Event in collaboration with The Ministry of Skill Development & Entrepreneurship. You get will Certificate by the Ministry of Skill Development & Entrepreneurship of India and also Internship Opportunities for Best Performers in the Grand 1-Day Virtual Event of AI-for-India 2.0.
# Celebrate the Rewards together with Friends Now you'd win Amazon Gift Vouchers, GUVI Premium Passes & more based on your referral sign-up count. While your friends will get Certificate by the Ministry of Skill Development & Entrepreneurship of India and also Internship Opportunities for Best Performers in the Grand 1-Day Virtual Event of AI-for-India 2.0. Isn't this referral program a Win-Win solution for all?
# Previous Next Start Referring 1 Free Sign-up = 1 Verified Referral More Verified Referrals = Multiple Rewards No. of Sign Ups 0 No. of Verified Referrals 0 No. of Redeemable Referrals 0 Note: Please make sure that the people, who sign up through your referral, verify their account to count them as a verified referral Refer your friends, Claim your Rewards!
# FAQs
# * How can I register for this event? You need to fill in the basic details in the above form and register yourself for free.
# * Do I have to pay fees to participate in this event? AI-for-India 2.0 initiative is absolutely free for registration & learning.
# * Will I get certification for participating in this event? Yes, you will receive a participation certificate accredited by the Ministry of Skill Development & Entrepreneurship along with GUVI for attending the main virtual AI event on 15 August 2023.
# * How do I participate in the Refer & Earn Reward Program? The offer code will be shown instantly upon claiming the reward.
# * How will I receive the Voucher/Coupon code? We will reach you through your registered email address or contact number within 7-14 working days to collect your delivery address information for sending the rewards.
# * How I will receive the earned reward items? Please note that each signup is counted as valid referral only on the event of verifying the account information including both email and contact number
# * Why is my referral sign-up count not updating itself? Please note that each signup is counted as a valid referral only upon the event of verifying the account information that includes both email address and contact number.
# * Refer More Friends, Get More Rewards, Repeat! Start Referring Login to Refer
#
#
# The referral program offered through GUVI's AI for India Program 2.0 is designed to create a mutually beneficial arrangement for all participants involved. By actively referring friends and family to enroll in this prestigious initiative, participants not only contribute to the program's growth but also stand to earn a diverse range of rewards based on the number of verified sign-ups they achieve. These rewards are enticing and varied, ranging from Amazon Gift Vouchers to valuable discount coupons and exclusive GUVI premium passes.
# For those who accept the referral and sign up for the AI for India Program 2.0, the benefits are equally substantial. Each new enrollee receives a prestigious Certificate from the Ministry of Skill Development & Entrepreneurship of India, recognizing their participation in what is heralded as India's largest virtual AI Event. Moreover, participants are eligible for sought-after internship opportunities, particularly those who excel during the Grand 1-Day Virtual Event of AI-for-India 2.0.
# The beauty of this referral program lies in its equitable "win-win" nature. Referrers gain tangible rewards for their efforts while their referrals gain access to unparalleled learning opportunities and career advancements. This synergy ensures that both parties can celebrate achievements together, fostering a sense of community and shared success.
# To participate, individuals simply need to log in, initiate the referral process, and witness their referral count grow with each verified sign-up. This not only unlocks more rewards but also expands the community of learners benefiting from this transformative AI initiative. It's a testament to GUVI's commitment to empowering individuals through education and skill development, making a significant impact in the realm of artificial intelligence education in India and beyond.
# Celebrate the Rewards together with Friends
# Now you'd win Amazon Gift Vouchers, GUVI Premium Passes & more based on your referral sign-up count. While your friends will get Certificate by the Ministry of Skill Development & Entrepreneurship of India and also Internship Opportunities for Best Performers in the Grand 1-Day Virtual Event of AI-for-India 2.0. Isn't this referral program a Win-Win solution for all?
# Referral Details
# 1 Free Sign-up = 1 Verified Referral
# More Verified Referrals = Multiple Rewards
# Note: Please make sure that the people who sign up through your referral verify their account to count them as a verified referral.
# Refer to your friends, Claim your Rewards!
# FAQs
# * How can I register for this event?
# You need to fill in the basic details in the above form and register yourself for free.
# * Do I have to pay fees to participate in this event?
# AI-for-India 2.0 initiative is absolutely free for registration & learning.
# * Will I get certification for participating in this event?
# Yes, you will receive a participation certificate accredited by the Ministry of Skill Development & Entrepreneurship along with GUVI for attending the main virtual AI event on 15 August 2023.
# * How do I participate in the Refer & Earn Reward Program?
# The offer code will be shown instantly upon claiming the reward.
# * How will I receive the Voucher/Coupon code?
# We will reach you through your registered email address or contact number within 7-14 working days to collect your delivery address information for sending the rewards.
# * How will I receive the earned reward items?
# Please note that each signup is counted as valid referral only upon verifying the account information including both email and contact number.
# * Why is my referral sign-up count not updating itself?
# Please note that each signup is counted as a valid referral only upon verifying the account information that includes both email address and contact number.
# How I will receive the earned reward items?
# Please note that each signup is counted as a valid referral only upon verifying the account information including both email and contact number.
# Why is my referral sign-up count not updating itself?
# Please note that each signup is counted as a valid referral only upon verifying the account information that includes both email address and contact number.
# Refer More Friends, Get More Rewards, Repeat!
# Start Referring
# Login to Refer
# ________________
#
#
# Get Rewarded with our Referral program:
# * Register to GUVI through your email. Verify your email address using the activation link.
# * Click left on the menu & go to our referral page. Find your "Unique Invite link" at the top.
# * Share your referral link with your friends & family.
# * Each successful sign-up through your referral link counts.
# * You can see the number of verified referrals on the scoreboard.
# * Redeem exciting rewards like Amazon Vouchers, headset & Apple products, once they reach a certain number.
# * It's the WIN-WIN season, More signups = Great Rewards!!
# Part 1: About GUVI and Course Offerings
# About GUVI: GUVI Geek Networks Private Limited, incubated by IIT-M and IIM-A, stands as a pioneering Ed-tech company offering personalized learning solutions. Their platform specializes in online learning, upskilling, and recruitment opportunities, uniquely delivering technical skills in vernacular languages to cater to diverse learner backgrounds.
# Course Categories: GUVI's course offerings are diverse and comprehensive, spanning self-paced courses, live classes, and interactive practice platforms. Self-paced courses cover Programming Languages like Python, Java, and C++, along with Web Development, Mobile App Development, Data Science, Machine Learning, and Database and Cloud Computing. Live classes are available in disciplines such as Full Stack Development, Data Science, Automation & Testing, UI/UX Design, DevOps, Data Engineering, and Business Analytics with Digital Marketing. Interactive practice platforms like Codekata, Webkata, and IDE provide hands-on experience and skill enhancement opportunities.
# Resources: Additional resources include Learn Hub, Blogs, Forums, and App Downloads, enhancing the learning experience with access to valuable educational content and community interaction. GUVI also offers referral programs and rewards to incentivize user engagement and growth within its learning ecosystem.
# ________________
#
#
# Part 2: Special Programs and Achievements
# Key Programs: GUVI features specialized programs designed to meet industry demands and career aspirations. The ZEN Class is an intensive bootcamp offering live online classes and guaranteed job placement support in disciplines such as Full Stack Development, Data Science, Automation & Testing, UI/UX Design, and DevOps. Corporate Solutions cater to organizational needs through tailored training suites, freshers hiring, lateral hiring, HYRE assessments, and end-to-end campus hiring solutions. HackerKid provides essential coding classes tailored for K-12 students, nurturing young talent in foundational tech skills.
# Achievements: Recognized for excellence, GUVI has received accolades such as the Best Online Personalized Learning Programs Award from ENTREPRENEUR INDIA and the National Achievers Award from ZEE Digital in 2022. They hold a notable record for the highest number of users participating in an online programming lesson within 24 hours, highlighting their impact and reach in the Ed-tech space.
# ________________
#
#
# Part 3: Community, Support, and Testimonials
# Community and Support: GUVI fosters a vibrant community environment through its dedicated technical forum, providing a platform for discussions on tech-related queries, software upgrades, and industry trends. Queries are promptly addressed by knowledgeable tech experts within 48 hours, ensuring a supportive learning environment. Mentorship programs offer personalized guidance to learners, empowering them to navigate their educational journey effectively.
# Certifications: Upon course completion, learners receive certificates recognized for their educational achievements, valuable for showcasing skills to prospective employers and advancing career opportunities.
# Testimonials: Testimonials from users like Rakesh, a Software Developer, underscore the effectiveness of GUVI's programs. Rakesh highlighted the ZEN course's placement support, which facilitated job offers from multiple companies and ultimately led to a position at iQuanti India Pvt. Ltd.
# Additional Information: GUVI emphasizes interactive learning platforms where users engage in hands-on activities such as coding challenges and real-world projects. Rewards and referral programs incentivize user participation across platforms like Codekata and Webkata, offering exciting rewards such as iPhones and Amazon vouchers to further enhance engagement and learning outcomes.
# About GUVI
# GUVI Geek Networks Private Limited is an Ed-tech company incubated by IIT-M and IIM-A, aimed at offering personalized learning solutions. The platform focuses on providing skill development in various technology domains through online courses, interactive practice platforms, and live classes. GUVI's mission is to bridge the skill gap in the tech industry by making quality education accessible to learners worldwide, including non-English speakers, by offering courses in vernacular languages.
# Course Offerings
# GUVI offers a diverse range of courses catering to different tech domains. Their self-paced courses cover programming languages like Python, Java, and C++, as well as web development, mobile app development, data science, machine learning, database management, and cloud computing. Additionally, live classes focus on full-stack development, data science, automation and testing, UI/UX design, DevOps, data engineering, and business analytics with digital marketing. These courses emphasize hands-on learning with real-world projects and interactive sessions to ensure practical understanding.
# Interactive Practice Platforms
# GUVI's interactive practice platforms are designed to enhance learning through practical application. Codekata offers over 1500 coding problems to improve programming skills, while Webkata focuses on modern web development practices using HTML, CSS, and JavaScript. The Debugging platform provides a series of exercises to sharpen debugging skills. GUVI also offers an Integrated Development Environment (IDE) that supports multiple programming languages, enabling users to write, edit, run, test, and debug their code seamlessly.
# Key Programs
# GUVI's flagship program, ZEN Class, is an intensive bootcamp with live online classes and guaranteed job placement support. It includes courses on full-stack development, data science, automation and testing, UI/UX design, and DevOps. The Corporate Solutions program offers comprehensive training, hiring support, and assessment tools for companies looking to upskill their workforce or recruit trained freshers. HackerKid is a specialized coding program for K-12 students, fostering early interest in technology and programming.
# Community and Support
# GUVI fosters a strong learning community through forums, discussion boards, and collaborative projects. Their technical community platform allows users to discuss tech doubts, software upgrades, and trending news, with queries addressed by tech experts within 48 hours. Personalized mentorship is available to guide learners through their educational journey. GUVI also offers certificates of completion for their courses, which are valuable for job applications and professional growth.
# Achievements and Awards
# GUVI has been recognized for its innovative approach to online education with awards such as the Best Online Personalized Learning Program by ENTREPRENEUR INDIA and the National Achievers Award by ZEE Digital in 2022. The platform also holds a record for the most users participating in an online programming lesson within 24 hours, showcasing its wide reach and impact on the tech education landscape.
# Testimonials and Success Stories
# GUVI's success is reflected in the testimonials of its learners. For instance, Rakesh, a software developer, highlighted the value of the ZEN course's placement support, which led to multiple job offers and a position at iQuanti India Pvt. Ltd. Such success stories underline the effectiveness of GUVI's training programs and their role in transforming careers.
# Additional Resources and Features
# GUVI offers a variety of resources to support learners, including Learn Hub, blogs, forums, and mobile apps. The platform's referral programs and rewards system incentivize users to engage with the content and share their experiences. Through interactive learning platforms like Codekata and Webkata, GUVI ensures that learners not only gain theoretical knowledge but also practical skills that are crucial for their professional development.
# Frequently Asked Questions
# GUVI is an online platform offering various tech courses, bootcamps, and skill development programs in multiple languages to make learning accessible to everyone. You can contact GUVI via email at support@guvi.in or through the contact form on their website. To enroll, visit the course library on the GUVI website, select your desired course, and follow the enrollment instructions. Prerequisites vary by course. Some advanced courses may require prior knowledge in specific areas, while others are designed for beginners. GUVI offers self-paced courses, live classes (ZEN Class), and corporate training programs. Topics range from programming and web development to data science and AI. For technical support, you can reach out to the GUVI support team via the support section on their website. GUVI provides certificates upon successful completion of the course and passing any required assessments. GUVI accepts various payment methods, including credit/debit cards, net banking, and digital wallets. GUVI has a refund policy that allows you to request a refund within a specified period after enrollment if you are not satisfied with the course. GUVI provides customized training solutions for corporate clients, including upskilling and reskilling programs. Codekata is GUVI's coding practice platform with over 1500 coding problems to help users enhance their programming skills. ZEN Class is an intensive bootcamp that includes live online classes and job placement support in various tech domains like full-stack development and data science. GUVI has an active community forum where learners can discuss topics, ask questions, and share knowledge.
# For more detailed information, you can visit the GUVI FAQ page. If you need additional specifics or have further questions, feel free to ask!
# Social Media and LinkedIn Platforms
# Follow GUVI on LinkedIn to stay updated with the latest news, courses, and events. The LinkedIn page is a great place to connect with industry professionals and fellow learners. Join the LinkedIn community to get insights from experts, participate in discussions, and access exclusive content. Stay connected with GUVI on social media platforms like Facebook, Twitter, and Instagram for regular updates and interactive sessions. The social media pages are filled with success stories, coding challenges, and motivational content to keep you inspired.
# About GUVI
# GUVI Geek Networks Private Limited is an Ed-tech company incubated by IIT-M and IIM-A, aimed at offering personalized learning solutions. The platform focuses on providing skill development in various technology domains through online courses, interactive practice platforms, and live classes. GUVI's mission is to bridge the skill gap in the tech industry by making quality education accessible to learners worldwide, including non-English speakers, by offering courses in vernacular languages.
# Course Offerings
# GUVI offers a diverse range of courses catering to different tech domains. Their self-paced courses cover programming languages like Python, Java, and C++, as well as web development, mobile app development, data science, machine learning, database management, and cloud computing. Additionally, live classes focus on full-stack development, data science, automation and testing, UI/UX design, DevOps, data engineering, and business analytics with digital marketing. These courses emphasize hands-on learning with real-world projects and interactive sessions to ensure practical understanding.
# Interactive Practice Platforms
# GUVI's interactive practice platforms are designed to enhance learning through practical application. Codekata offers over 1500 coding problems to improve programming skills, while Webkata focuses on modern web development practices using HTML, CSS, and JavaScript. The Debugging platform provides a series of exercises to sharpen debugging skills. GUVI also offers an Integrated Development Environment (IDE) that supports multiple programming languages, enabling users to write, edit, run, test, and debug their code seamlessly.
# Key Programs
# GUVI's flagship program, ZEN Class, is an intensive bootcamp with live online classes and guaranteed job placement support. It includes courses on full-stack development, data science, automation and testing, UI/UX design, and DevOps. The Corporate Solutions program offers comprehensive training, hiring support, and assessment tools for companies looking to upskill their workforce or recruit trained freshers. HackerKid is a specialized coding program for K-12 students, fostering early interest in technology and programming.
# Community and Support
# GUVI fosters a strong learning community through forums, discussion boards, and collaborative projects. Their technical community platform allows users to discuss tech doubts, software upgrades, and trending news, with queries addressed by tech experts within 48 hours. Personalized mentorship is available to guide learners through their educational journey. GUVI also offers certificates of completion for their courses, which are valuable for job applications and professional growth.
# Achievements and Awards
# GUVI has been recognized for its innovative approach to online education with awards such as the Best Online Personalized Learning Program by ENTREPRENEUR INDIA and the National Achievers Award by ZEE Digital in 2022. The platform also holds a record for the most users participating in an online programming lesson within 24 hours, showcasing its wide reach and impact on the tech education landscape.
# Testimonials and Success Stories
# GUVI's success is reflected in the testimonials of its learners. For instance, Rakesh, a software developer, highlighted the value of the ZEN course's placement support, which led to multiple job offers and a position at iQuanti India Pvt. Ltd. Such success stories underline the effectiveness of GUVI's training programs and their role in transforming careers.
# Additional Resources and Features
# GUVI offers a variety of resources to support learners, including Learn Hub, blogs, forums, and mobile apps. The platform's referral programs and rewards system incentivize users to engage with the content and share their experiences. Through interactive learning platforms like Codekata and Webkata, GUVI ensures that learners not only gain theoretical knowledge but also practical skills that are crucial for their professional development.
# Social Media and LinkedIn Platforms
# GUVI leverages social media platforms to enhance its reach, engage with its audience, and provide valuable educational content. The company's social media presence spans LinkedIn, Facebook, Twitter, Instagram, and YouTube, each serving a unique purpose and audience.
# LinkedIn Presence
# GUVI's LinkedIn profile is professionally managed, showcasing the company's mission, vision, and values. The profile includes comprehensive information about GUVI's services, course offerings, corporate partnerships, and success stories. The content strategy focuses on educational articles, course announcements, success stories, and webinars. GUVI uses interactive posts, hashtag campaigns, and networking opportunities to engage its audience.
# Social Media Engagement
# GUVI's Facebook page serves as a central hub for updates, community interaction, and promotional activities. The Twitter profile shares tech news, quick tips, and event promotions. The Instagram profile is visually appealing, showcasing the company's vibrant culture and engaging content. GUVI's YouTube channel offers tutorials, webinars, and success stories. The company's social media strategy emphasizes interactive content, community engagement, and impactful metrics to measure success.
# Community Impact and Engagement
# GUVI's social media presence is instrumental in building a vibrant and engaged learning community. Success stories and testimonials, motivational content, and interactive learning opportunities ensure that learning is a collaborative experience. GUVI's social media strategy effectively reaches a diverse audience, fosters a strong community, and continuously engages learners with valuable content.
#
#
# Conclusion
# GUVI Geek Networks Private Limited stands out as a leading Ed-tech platform that prioritizes accessibility, quality, and community. With a diverse range of courses, comprehensive webinars, multilingual content, and a growing community of learners, GUVI is making a significant impact in the tech education landscape.
# GUVI’s AI for India Program 2.0 is a transformative initiative aimed at democratizing access to artificial intelligence education and skills development across India. As part of this program, GUVI offers a comprehensive learning platform, virtual events, certifications, and internship opportunities, supported by the Ministry of Skill Development & Entrepreneurship. To amplify its impact, GUVI has introduced a robust referral program designed to engage participants and incentivize them to share this valuable opportunity with their networks.
# The referral program is structured to reward participants for referring others to join the AI for India Program 2.0. Below is a detailed breakdown of the steps involved:
# 1. Registration and Account Activation:
# * Registration: Participants begin by registering for the AI for India Program 2.0 through GUVI’s official platform.
# * Account Activation: Upon registration, participants receive a confirmation email and are required to verify their email address to activate their account.
# 2. Accessing Your Unique Referral Link:
# * Referral Section: Once registered and logged into their account, participants can navigate to the referral section provided in their dashboard.
# * Unique Referral Link: In this section, each participant is provided with a unique referral link. This link serves as the primary tool for tracking referrals and attributing them to the participant who shared it.
# 3. Sharing Your Referral Link:
# * Target Audience: Participants are encouraged to share their unique referral link with their network, including friends, family, colleagues, and peers who have an interest in artificial intelligence and skill development.
# * Communication Channels: Referral links can be shared through various channels such as email, social media platforms (e.g., Facebook, Twitter, LinkedIn), messaging apps (e.g., WhatsApp, Telegram), and personal blogs or websites.
# 4. Referral Validation and Rewards:
# * Verified Referrals: When someone clicks on the participant’s unique referral link and subsequently registers for the AI for India Program 2.0, their registration is counted as a referral.
# * Verification Process: To qualify as a verified referral, the new registrant must complete their profile setup, verify their email address, and possibly fulfill additional verification criteria set by GUVI.
# * Reward Milestones: Participants accumulate verified referrals over time. As they reach specific milestones in their referral count, they become eligible for rewards as outlined by the program guidelines.
# 5. Types of Rewards:
# * Reward Tiers: Rewards are structured in tiers based on the number of verified referrals achieved by the participant.
# * Examples of Rewards: Rewards may include Amazon Gift Vouchers, discount coupons for GUVI courses or merchandise, premium passes to future GUVI events, exclusive mentoring sessions, and recognition certificates.
# * Special Incentives: Participants who achieve exceptional referral performance may be eligible for special incentives such as featured profiles on GUVI’s platform or invitations to exclusive networking events.
# ...
#
#
# JavaScript: From basic syntax to advanced concepts like asynchronous programming, ES6 features, APIs, and frameworks such as React, Angular, and Vue.js. Projects include dynamic web applications and single-page applications.
#
#
# Web Development
# HTML & CSS: Basics of web design and development, responsive design, grid layouts, flexbox, and CSS frameworks like Bootstrap. Projects include creating static websites and interactive web pages.
#
#
# JavaScript Frameworks: Core concepts of React, Angular, and Vue.js, including component-based architecture, state management, and routing. Projects involve building dynamic, single-page applications.
#
#
# Backend Development: Focuses on Node.js and Express.js, server-side programming, building RESTful APIs, and integrating with databases. Projects include backend services for web applications.
#
#
# Full Stack Development: Combines front-end and back-end technologies, integrating HTML, CSS, JavaScript, Node.js, Express.js, and databases. Projects involve building complete web applications.
#
#
# Data Science and Machine Learning
# Data Analysis with Python and R: Data cleaning, exploratory data analysis, visualization, and statistical analysis using tools like Pandas, NumPy, Matplotlib, Seaborn, dplyr, and ggplot2.
#
#
# Machine Learning: Covers supervised and unsupervised learning algorithms, model evaluation, and feature engineering using tools like Scikit-learn, TensorFlow, and Keras. Projects include predictive modeling and clustering analysis.
#
#
# Deep Learning: Focuses on neural networks, including CNNs, RNNs, and GANs, using frameworks like TensorFlow and Keras. Projects include handwriting recognition, chatbots, and image generators.
#
#
# Data Engineering: End-to-end data pipeline, data ingestion, processing, storage, analysis, ETL processes, and big data technologies using tools like Apache Hadoop, Spark, and Kafka. Projects involve building data pipelines and processing large datasets.
#
#
# Mobile Development
# Android Development: Building Android apps using Java and Kotlin, covering Android components, UI/UX design, data storage, and third-party integration. Projects include weather apps, note-taking apps, and simple games.
#
#
# iOS Development: iOS app development using Swift, Xcode, UI design with Storyboards, and API integration. Projects include to-do list apps, photo gallery apps, and fitness trackers.
#
#
# Cybersecurity
# Ethical Hacking: Penetration testing and vulnerability assessment using tools like Metasploit, Nmap, and Wireshark. Topics include network scanning, exploitation, and post-exploitation techniques.
#
#
# Network Security: Principles of network security, including firewall configurations, intrusion detection systems, and secure network protocols. Practical experience with network setup and security.
#
#
# Cybersecurity Fundamentals: Basic concepts of threat models, cryptography, and risk management, using real-world case studies to implement security measures.
#
#
# Special Features and Services
# Codekata: An interactive coding practice platform with 1500+ problems designed to improve coding skills and logical thinking. Features real-time feedback, a leaderboard, and diverse topics covering algorithms, data structures, and language-specific challenges.
#
#
# Webkata: Focused on web development skills, offering interactive projects and guided learning paths for building web applications. Emphasizes real-world scenarios and feedback from mentors.
#
#
# MicroArc: Short, focused courses on specific technologies, designed for quick learning and immediate application. Includes up-to-date content on emerging technologies and industry trends.
#
#
# iHatch: An incubation program for startups, offering mentorship, resources, funding opportunities, networking, and workshops on entrepreneurship and innovation.
#
#
# Zen Class Overview
# Zen Class is an immersive training program designed to make learners job-ready. It focuses on hands-on learning and mentorship to ensure practical skills acquisition.
#
#
# Programs and Tracks Available:
# Full Stack Development: Covers front-end (HTML, CSS, JavaScript, React, Angular) and back-end (Node.js, Express.js, SQL, MongoDB) technologies. Projects include building complete web applications.
# Data Science and Machine Learning: Comprehensive understanding of data science, machine learning, data analysis, and deep learning. Tools include Python, R, TensorFlow, and Keras. Projects involve predictive modeling and image recognition.
# UI/UX Design: Focuses on design principles, prototyping tools (Figma, Adobe XD), user research, and usability testing. Projects include designing apps and websites.
# DevOps and Cloud Computing: Principles and practices of DevOps and cloud computing, including CI/CD, containerization, orchestration, and cloud services. Projects involve setting up CI/CD pipelines and deploying applications on cloud platforms.
# Additional Features
# GUVI IDE: An Integrated Development Environment for writing, editing, running, testing, and debugging code. Supports multiple programming languages and provides a debugger for JavaScript, Python, and Ruby.
#
#
# Forum: A technical community platform for discussing technical doubts, software upgrades, and trending tech news. Dedicated tech experts address queries within 48 hours.
#
#
# Rewards and Referral: Points earned through CodeKata, WebKata, and referrals can be redeemed for rewards such as iPhones and Amazon vouchers. The referral scheme allows users to share codes with peers to earn points.
#
#
# Corporate Programs
# GUVI also offers services for corporates, including:
#
#
# Corporate Training Suite: Customizable training programs for employees, covering various technical and soft skills.
# Hire Trained Freshers: Access to a pool of job-ready candidates trained by GUVI.
# Lateral Hiring: Assistance in hiring experienced professionals with specific skill sets.
# HYRE Assessment: A comprehensive assessment tool for evaluating candidates’ technical skills.
# End-to-End Campus Hiring: Complete solutions for campus recruitment, from candidate assessment to hiring.
# Success Stories and Impact
# GUVI has made significant strides in the edtech space, helping thousands of learners achieve their career goals. With a focus on practical learning and industry relevance, GUVI has built a strong community of learners and professionals. Their impact is evident through numerous success stories of learners who have transitioned into successful careers in technology.
#
#
# Conclusion
# GUVI stands as a testament to the power of accessible and inclusive education. By providing high-quality technical education in native languages, GUVI is breaking down barriers and creating opportunities for learners worldwide. Whether through their comprehensive courses, interactive platforms like Codekata and Webkata, or innovative programs like Zen Class, GUVI is committed to empowering the next generation of tech professionals.
#
#
# For more detailed information about GUVI, you can visit their LinkedIn page​ (Guvi)​.
#
#
# Comprehensive Details on GUVI: Continued
# GUVI's Educational Approach
# Pedagogical Innovation: GUVI's educational model is grounded in an innovative pedagogical framework that emphasizes interactive and practical learning. This approach is evident in the platform’s design, which includes features such as live coding sessions, peer-to-peer interaction, and real-time feedback mechanisms. By integrating gamification and project-based learning, GUVI ensures that learners not only acquire theoretical knowledge but also gain hands-on experience that is crucial for their professional development.
#
#
# Language Accessibility: One of GUVI's most distinguishing features is its focus on vernacular languages. This strategic choice addresses a critical barrier in education—language. By offering courses in Tamil, Telugu, Hindi, Kannada, Bengali, and more, GUVI empowers students from various linguistic backgrounds to learn complex technical subjects without the additional hurdle of language comprehension. This approach not only widens GUVI’s reach but also fosters a more inclusive learning environment.
#
#
# Detailed Course Descriptions
# Programming Languages:
#
#
# Python: GUVI's Python course starts with basic syntax and data types, progressing to more advanced topics such as object-oriented programming, file handling, and web scraping. The curriculum also covers data analysis and visualization using libraries like Pandas, NumPy, and Matplotlib. Students engage in projects such as building web applications, data analysis pipelines, and automation scripts.
# Java: The Java course offers comprehensive coverage from basic syntax and data types to advanced topics like collections framework, multithreading, and Java EE. Practical projects include developing desktop applications, web services, and Android applications.
# JavaScript: This course includes fundamentals and advanced JavaScript, with a focus on ES6+ features, asynchronous programming, and frameworks like React, Angular, and Vue.js. Projects involve creating dynamic web applications, single-page applications (SPAs), and integrating with RESTful APIs.
# Web Development:
#
#
# Frontend Development: Courses cover HTML5, CSS3, and JavaScript, with an emphasis on responsive design and frameworks like Bootstrap. Learners work on projects such as creating responsive websites, interactive user interfaces, and SPA architectures.
# Backend Development: Focuses on server-side technologies including Node.js, Express.js, and database integration with SQL and NoSQL databases. Projects include building RESTful APIs, microservices, and backend services for web applications.
# Full Stack Development: Combines frontend and backend technologies, teaching integration of client-side and server-side programming. Students build full-fledged web applications, employing the MERN (MongoDB, Express.js, React, Node.js) or MEAN (MongoDB, Express.js, Angular, Node.js) stacks.
# Data Science and Machine Learning:
#
#
# Data Analysis: Courses on data analysis using Python and R cover data cleaning, exploratory data analysis (EDA), and data visualization with tools like Matplotlib, Seaborn, and ggplot2. Projects involve analyzing datasets, creating visualizations, and presenting data-driven insights.
# Machine Learning: Focuses on algorithms for supervised and unsupervised learning, model evaluation techniques, and feature engineering. Tools include Scikit-learn, TensorFlow, and Keras. Practical applications range from predictive modeling to clustering and natural language processing (NLP).
# Deep Learning: Explores neural networks, including convolutional neural networks (CNNs) for image processing, recurrent neural networks (RNNs) for sequence modeling, and generative adversarial networks (GANs). Projects include developing image recognition systems, chatbots, and generative models.
# Mobile Development:
#
#
# Android Development: This course teaches Android app development using Java and Kotlin, covering Android SDK, UI design, data storage, and third-party integrations. Projects include developing complete Android applications like weather apps, social media apps, and utility apps.
# iOS Development: Covers iOS app development using Swift, Xcode, and Apple’s frameworks. Students learn to design user interfaces, integrate APIs, and deploy apps. Projects range from simple utilities to complex applications with backend integration.
# Cybersecurity:
#
#
# Ethical Hacking: Provides training in penetration testing, vulnerability assessment, and security auditing using tools like Metasploit, Nmap, and Wireshark. Hands-on projects involve ethical hacking scenarios and security analysis.
# Network Security: Covers principles of network security, including configuration of firewalls, intrusion detection systems, and secure networking protocols. Practical labs involve setting up secure networks and mitigating security threats.
# Cybersecurity Fundamentals: Introduces the basics of cybersecurity, including threat modeling, cryptography, and risk management. Case studies and practical exercises help learners understand and implement security measures.
# Specialized Programs and Features
# Zen Class: This is an immersive bootcamp designed to transform learners into industry-ready professionals. The program offers:
#
#
# 360-degree Career Guidance: Comprehensive support including resume building, interview preparation, and soft skills training.
# Professional Mentorship: Guidance from industry experts and experienced mentors to help learners navigate their career paths.
# Placement Support: Assistance in securing job opportunities through partnerships with over 200 companies.
# Codekata: An interactive coding practice platform with over 1500 problems to enhance coding skills. Features include real-time feedback, leaderboards, and a wide range of topics covering algorithms, data structures, and language-specific challenges.
#
#
# Webkata: Focuses on improving web development skills through interactive projects and guided learning paths. Emphasizes real-world scenarios and provides feedback from mentors.
#
#
# MicroArc: Offers short, focused courses on specific technologies. These micro-courses are designed for quick learning and immediate application, covering the latest in emerging technologies and industry trends.
#
#
# iHatch: An incubation program for startups that offers resources, mentorship, funding opportunities, and networking. The program includes workshops on entrepreneurship and innovation, providing a comprehensive support system for budding entrepreneurs.
#
#
# Corporate Training and Services
# GUVI provides various services for corporate clients, aimed at upskilling their workforce and streamlining recruitment processes:
#
#
# Corporate Training Suite: Customizable training programs tailored to the needs of companies, covering technical and soft skills.
# Hire Trained Freshers: Access to a pool of job-ready candidates trained by GUVI, facilitating efficient recruitment.
# Lateral Hiring: Assistance in hiring experienced professionals with specific skill sets.
# HYRE Assessment: A comprehensive tool for evaluating candidates’ technical skills, aiding in the hiring process.
# End-to-End Campus Hiring: Complete solutions for campus recruitment, including candidate assessment and hiring.
# Community and Social Impact
# GUVI has made significant contributions to the educational landscape, impacting thousands of learners and professionals. Some key initiatives and their impacts include:
#
#
# AI-for-India Initiative: A large-scale event in partnership with AICTE, aimed at upskilling individuals in Python programming. This initiative saw massive participation, highlighting GUVI's commitment to making advanced technology education accessible.
# AI-for-Women Campaign: Focused on empowering women through free tech upskilling opportunities, aiming to bridge the gender gap in the tech industry.
# Future Plans
# GUVI is continually expanding its offerings and enhancing its platform to stay ahead in the fast-evolving EdTech sector. Future plans include:
#
#
# Broadening Course Offerings: Introducing new courses in cutting-edge technologies and expanding existing ones to cover more advanced topics.
# Enhancing the Learning Platform: Incorporating AI and machine learning to provide personalized learning experiences and improve engagement.
# Expanding Global Reach: Reaching more learners across India and globally by offering courses in more languages and collaborating with international educational institutions.
# Fostering Industry Partnerships: Strengthening partnerships with leading tech companies to provide better placement opportunities and keep the curriculum industry-relevant.
# Conclusion
# GUVI's innovative approach to education, combined with its focus on inclusivity and quality, has made it a significant player in the EdTech industry. By offering courses in multiple languages, providing hands-on learning experiences, and ensuring industry relevance, GUVI continues to empower learners and professionals to excel in the technology sector.

# %%
pip install accelerate -U
# Out:
# Collecting accelerate
#   Downloading accelerate-0.31.0-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.3.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.23.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.15.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.5.40)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.31.0

# %%
import accelerate
print(accelerate.__version__)
# Out:
# 0.31.0

# %%
# !pip install accelerate>=0.21.0

# %%
pip install transformers[torch]
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.42.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.15.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.23.4)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.4)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.31.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.3.0+cu121)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers[torch]) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch]) (12.5.40)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[torch]) (1.3.0)

# %%
# !pip show accelerate
# Out:
# Name: accelerate
# Version: 0.31.0
# Summary: Accelerate
# Home-page: https://github.com/huggingface/accelerate
# Author: The HuggingFace team
# Author-email: zach.mueller@huggingface.co
# License: Apache
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: huggingface-hub, numpy, packaging, psutil, pyyaml, safetensors, torch
# Required-by:

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments, TextDataset, DataCollatorForLanguageModeling

# Load pre-trained model and tokenizer
model_name = "gpt2"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Input file path (replace with your actual input file)
input_file = "/content/Guvi - Cleaned (2).txt"

# Function to load dataset
def load_dataset(file_path, tokenizer):
    return TextDataset(
        tokenizer=tokenizer,
        file_path=file_path,
        block_size=128,  # Adjust block size as needed
    )

# Create dataset using raw text file
train_dataset = load_dataset(input_file, tokenizer)

# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    overwrite_output_dir=True,
    num_train_epochs=3,
    per_device_train_batch_size=4,
    save_steps=10_000,
    save_total_limit=2,
)

# Initialize data collator
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False,
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
)

# Fine-tune the model
trainer.train()

# Save the fine-tuned model and tokenizer
model.save_pretrained("./fine_tuned_model")
tokenizer.save_pretrained("./fine_tuned_model")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/data/datasets/language_modeling.py:53: FutureWarning: This dataset will be removed from the library soon, preprocessing should be handled with the 🤗 Datasets library. You can have a look at this example script for pointers: https://github.com/huggingface/transformers/blob/main/examples/pytorch/language-modeling/run_mlm.py
#   warnings.warn(
#     <div>
#
#       <progress value='102' max='102' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [102/102 19:34, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ('./fine_tuned_model/tokenizer_config.json',
#  './fine_tuned_model/special_tokens_map.json',
#  './fine_tuned_model/vocab.json',
#  './fine_tuned_model/merges.txt',
#  './fine_tuned_model/added_tokens.json')

# %%
#!pip install transformers

from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch

# Load the fine-tuned model and tokenizer
model_name_or_path = "/content/fine_tuned_model"
model = GPT2LMHeadModel.from_pretrained(model_name_or_path)
tokenizer = GPT2Tokenizer.from_pretrained(model_name_or_path)

# Move the model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define the text generation function
def generate_text(model, tokenizer, seed_text, max_length=100, temperature=1.0, num_return_sequences=1):
    # Tokenize the input text
    input_ids = tokenizer.encode(seed_text, return_tensors='pt').to(device)

    # Generate text
    with torch.no_grad():
        output = model.generate(
            input_ids,
            max_length=max_length,
            temperature=temperature,
            num_return_sequences=num_return_sequences,
            do_sample=True,
            top_k=50,
            top_p=0.95,
        )

    # Decode the generated text
    generated_texts = []
    for i in range(num_return_sequences):
        generated_text = tokenizer.decode(output[i], skip_special_tokens=True)
        generated_texts.append(generated_text)

    return generated_texts

# Test the model
seed_text = "Guvi"
generated_texts = generate_text(model, tokenizer, seed_text, max_length=20, temperature=0.7, num_return_sequences=3)

for i, text in enumerate(generated_texts):
    print(f"Generated Text {i + 1}:\n{text}\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Text 1:
# Guvi-based IT companies that offer education in the IT industry. Their platform includes over 1,
#
# Generated Text 2:
# Guvi), provides a comprehensive guide to the various types of learning, covering topics such as coding,
#
# Generated Text 3:
# Guvi) and the web-based platform, which allows users to create their own profiles and share

# %%
# !pip install transformers fastapi uvicorn nest-asyncio pyngrok
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (0.111.0)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.10/dist-packages (0.30.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Collecting pyngrok
#   Downloading pyngrok-7.1.6-py3-none-any.whl (22 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi) (0.37.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi) (2.7.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (4.12.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from fastapi) (0.0.4)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (0.27.0)
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.10/dist-packages (from fastapi) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from fastapi) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from fastapi) (5.10.0)
# Requirement already satisfied: orjson>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from fastapi) (3.10.5)
# Requirement already satisfied: email_validator>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (2.2.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi) (2.6.1)
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi) (3.7)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.10/dist-packages (from fastapi-cli>=0.0.2->fastapi) (0.12.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (1.0.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (1.3.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2023.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.2->fastapi) (2.1.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.18.4)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.23.0->fastapi) (1.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (0.1.2)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.1.6

# %%
from fastapi import FastAPI, Request
from pydantic import BaseModel
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
import nest_asyncio
from pyngrok import ngrok
import uvicorn

app = FastAPI()

# Load the fine-tuned model and tokenizer
model_name_or_path = "./fine_tuned_model"
model = GPT2LMHeadModel.from_pretrained(model_name_or_path)
tokenizer = GPT2Tokenizer.from_pretrained(model_name_or_path)

# Move the model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

class Query(BaseModel):
    text: str

@app.post("/generate/")
async def generate_text(query: Query):
    input_ids = tokenizer.encode(query.text, return_tensors="pt").to(device)
    output = model.generate(input_ids, max_length=100, num_return_sequences=1, do_sample=True, top_k=50, top_p=0.95)
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return {"generated_text": generated_text}

@app.get("/generatee/")
async def generate_text(text: str):
    input_ids = tokenizer.encode(text, return_tensors="pt").to(device)
    output = model.generate(input_ids, max_length=100, num_return_sequences=1, do_sample=True, top_k=50, top_p=0.95)
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return {"generated_text": generated_text}

# Authenticate ngrok
from pyngrok import conf, ngrok
conf.get_default().auth_token = "2hDZVZnb996LAuUHNog0mPmk1MK_2xWzW8sTvhw73AQ3Sr1bK"  # Replace with your new token

# Start ngrok
ngrok_tunnel = ngrok.connect(8000)
print("Public URL:", ngrok_tunnel.public_url)

# Allow nested asyncio
nest_asyncio.apply()

# Run the FastAPI app
uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
# INFO:     Started server process [6411]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# Public URL: https://0cfb-34-73-94-253.ngrok-free.app
# INFO:     117.201.33.182:0 - "GET / HTTP/1.1" 404 Not Found
# INFO:     117.201.33.182:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# INFO:     117.201.33.182:0 - "GET /generatee/?text=Guvi%20is HTTP/1.1" 200 OK
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# INFO:     117.201.33.182:0 - "GET /generatee/?text=Guvi%20is HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [6411]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-be9a9ee220d8> in <cell line: 49>()
#      47
#      48 # Run the FastAPI app
# ---> 49 uvicorn.run(app, host="0.0.0.0", port=8000)
#
# /usr/local/lib/python3.10/dist-packages/uvicorn/main.py in run(app, host, port, uds, fd, loop, http, ws, ws_max_size, ws_max_queue, ws_ping_interval, ws_ping_timeout, ws_per_message_deflate, lifespan, interface, reload, reload_dirs, reload_includes, reload_excludes, reload_delay, workers, env_file, log_config, log_level, access_log, proxy_headers, server_header, date_header, forwarded_allow_ips, root_path, limit_concurrency, backlog, limit_max_requests, timeout_keep_alive, timeout_graceful_shutdown, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_version, ssl_cert_reqs, ssl_ca_certs, ssl_ciphers, headers, use_colors, app_dir, factory, h11_max_incomplete_event_size)
#     575             Multiprocess(config, target=server.run, sockets=[sock]).run()
#     576         else:
# --> 577             server.run()
#     578     finally:
#     579         if config.uds and os.path.exists(config.uds):
#
# /usr/local/lib/python3.10/dist-packages/uvicorn/server.py in run(self, sockets)
#      63     def run(self, sockets: list[socket.socket] | None = None) -> None:
#      64         self.config.setup_event_loop()
# ---> 65         return asyncio.run(self.serve(sockets=sockets))
#      66
#      67     async def serve(self, sockets: list[socket.socket] | None = None) -> None:
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in run(main, debug)
#      28         task = asyncio.ensure_future(main)
#      29         try:
# ---> 30             return loop.run_until_complete(task)
#      31         finally:
#      32             if not task.done():
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in run_until_complete(self, future)
#      90                 f._log_destroy_pending = False
#      91             while not f.done():
# ---> 92                 self._run_once()
#      93                 if self._stopping:
#      94                     break
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in _run_once(self)
#     131
#     132                 try:
# --> 133                     handle._run()
#     134                 finally:
#     135                     # restore the current task
#
# /usr/lib/python3.10/asyncio/events.py in _run(self)
#      78     def _run(self):
#      79         try:
# ---> 80             self._context.run(self._callback, *self._args)
#      81         except (SystemExit, KeyboardInterrupt):
#      82             raise
#
# /usr/lib/python3.10/asyncio/tasks.py in __wakeup(self, future)
#     313             # instead of `__next__()`, which is slower for futures
#     314             # that return non-generator iterators from their `__iter__`.
# --> 315             self.__step()
#     316         self = None  # Needed to break cycles when an exception occurs.
#     317
#
# /usr/lib/python3.10/asyncio/tasks.py in __step(***failed resolving arguments***)
#     230                 # We use the `send` method directly, because coroutines
#     231                 # don't have `__iter__` and `__next__` methods.
# --> 232                 result = coro.send(None)
#     233             else:
#     234                 result = coro.throw(exc)
#
# /usr/local/lib/python3.10/dist-packages/uvicorn/server.py in serve(self, sockets)
#      66
#      67     async def serve(self, sockets: list[socket.socket] | None = None) -> None:
# ---> 68         with self.capture_signals():
#      69             await self._serve(sockets)
#      70
#
# /usr/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     140         if typ is None:
#     141             try:
# --> 142                 next(self.gen)
#     143             except StopIteration:
#     144                 return False
#
# /usr/local/lib/python3.10/dist-packages/uvicorn/server.py in capture_signals(self)
#     326         # done LIFO, see https://stackoverflow.com/questions/48434964
#     327         for captured_signal in reversed(self._captured_signals):
# --> 328             signal.raise_signal(captured_signal)
#     329
#     330     def handle_exit(self, sig: int, frame: FrameType | None) -> None:
#
# KeyboardInterrupt:

# %%
import requests

# Define the public URL and the endpoint
public_url = "https://0cfb-34-73-94-253.ngrok-free.app/"
endpoint = "/generate/"

# Combine the URL and endpoint
url = public_url + endpoint

# Define the data to be sent in the POST request
data = {
    "text": "Guvi is known for"
}

try:
    # Send the POST request
    response = requests.post(url, json=data)

    # Check if the request was successful
    if response.status_code == 200:
        # Attempt to parse JSON response
        try:
            json_response = response.json()
            print("Response:", json_response)
        except json.JSONDecodeError as json_err:
            print(f"Failed to decode JSON response: {json_err}")
            print("Response text:", response.text)
    else:
        print(f"Request failed with status code {response.status_code}: {response.text}")

except requests.RequestException as req_err:
    print(f"Request error: {req_err}")
# Out:
# Request failed with status code 404: <!DOCTYPE html>
# <html class="h-full" lang="en-US" dir="ltr">
#   <head>
#     <link rel="preload" href="https://cdn.ngrok.com/static/fonts/euclid-square/EuclidSquare-Regular-WebS.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://cdn.ngrok.com/static/fonts/euclid-square/EuclidSquare-RegularItalic-WebS.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://cdn.ngrok.com/static/fonts/euclid-square/EuclidSquare-Medium-WebS.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://cdn.ngrok.com/static/fonts/euclid-square/EuclidSquare-Semibold-WebS.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://cdn.ngrok.com/static/fonts/euclid-square/EuclidSquare-MediumItalic-WebS.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://cdn.ngrok.com/static/fonts/ibm-plex-mono/IBMPlexMono-Text.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://cdn.ngrok.com/static/fonts/ibm-plex-mono/IBMPlexMono-TextItalic.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://cdn.ngrok.com/static/fonts/ibm-plex-mono/IBMPlexMono-SemiBold.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <link rel="preload" href="https://cdn.ngrok.com/static/fonts/ibm-plex-mono/IBMPlexMono-SemiBoldItalic.woff" as="font" type="font/woff" crossorigin="anonymous" />
#     <meta charset="utf-8">
#     <meta name="author" content="ngrok">
#     <meta name="description" content="ngrok is the fastest way to put anything on the internet with a single command.">
#     <meta name="robots" content="noindex, nofollow">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link id="style" rel="stylesheet" href="https://cdn.ngrok.com/static/css/error.css">
#     <noscript>Tunnel 0cfb-34-73-94-253.ngrok-free.app not found (ERR_NGROK_3200)</noscript>
#     <script id="script" src="https://cdn.ngrok.com/static/js/error.js" type="text/javascript"></script>
#   </head>
#   <body class="h-full" id="ngrok">
#     <div id="root" data-payload="eyJjZG5CYXNlIjoiaHR0cHM6Ly9jZG4ubmdyb2suY29tLyIsImNvZGUiOiIzMjAwIiwibWVzc2FnZSI6IlR1bm5lbCAwY2ZiLTM0LTczLTk0LTI1My5uZ3Jvay1mcmVlLmFwcCBub3QgZm91bmQiLCJ0aXRsZSI6Ik5vdCBGb3VuZCJ9"></div>
#   </body>
# </html>

# %%
# !pip install streamlit transformers torch
# Out:
# Collecting streamlit
#   Downloading streamlit-1.36.0-py2.py3-none-any.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 18.0 MB/s eta 0:00:00
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.25.2)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.4.1)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 9.8 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 27.1 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Collecting watchdog<5,>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.1-py3-none-manylinux2014_x86_64.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.40)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Installing collected packages: watchdog, smmap, pydeck, gitdb, gitpython, streamlit
# Successfully installed gitdb-4.0.11 gitpython-3.1.43 pydeck-0.9.1 smmap-5.0.1 streamlit-1.36.0 watchdog-4.0.1

# %%
# %%writefile app.py
import streamlit as st
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch

# Load the fine-tuned model and tokenizer
#model_name_or_path = "./fine_tuned_model"
model_name_or_path = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name_or_path)
tokenizer = GPT2Tokenizer.from_pretrained(model_name_or_path)

# Move the model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define the text generation function
def generate_text(model, tokenizer, seed_text, max_length=100, temperature=1.0, num_return_sequences=1):
    input_ids = tokenizer.encode(seed_text, return_tensors='pt').to(device)
    with torch.no_grad():
        output = model.generate(
            input_ids,
            max_length=max_length,
            temperature=temperature,
            num_return_sequences=num_return_sequences,
            do_sample=True,
            top_k=50,
            top_p=0.95,
        )
    generated_texts = [tokenizer.decode(output[i], skip_special_tokens=True) for i in range(num_return_sequences)]
    return generated_texts

# Streamlit app
st.title("Text Generation with GPT-2")
st.write("This app generates text using a fine-tuned GPT-2 model. Enter a prompt and the model will generate a continuation.")

seed_text = st.text_input("Enter your prompt:", "Google is known for")
max_length = st.slider("Max Length:", min_value=50, max_value=500, value=100)
temperature = st.slider("Temperature:", min_value=0.1, max_value=2.0, value=1.0)

if st.button("Generate"):
    with st.spinner("Generating text..."):
        generated_texts = generate_text(model, tokenizer, seed_text, max_length, temperature)
        for i, generated_text in enumerate(generated_texts):
            st.subheader(f"Generated Text {i + 1}")
            st.write(generated_text)
# Out:
# Writing app.py

# %%
# !pip install pyngrok
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (7.1.6)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)

# %%
from pyngrok import conf, ngrok
import subprocess
import time

# Authenticate ngrok
conf.get_default().auth_token = "2hDZVZnb996LAuUHNog0mPmk1MK_2xWzW8sTvhw73AQ3Sr1bK"

# Run the Streamlit app in the background
process = subprocess.Popen(['streamlit', 'run', 'app.py'])

# Give the Streamlit app a few seconds to start
time.sleep(5)

# Expose the Streamlit app to the web using ngrok
public_url = ngrok.connect(addr="8501")
print(f"Public URL: {public_url}")

# Keep the Colab cell running
try:
    while True:
        time.sleep(1)
except KeyboardInterrupt:
    print("Stopping Streamlit app...")
    process.terminate()
    ngrok.disconnect(public_url)
    ngrok.kill()
# Out:
# Public URL: NgrokTunnel: "https://701c-34-73-94-253.ngrok-free.app" -> "http://localhost:8501"
# Stopping Streamlit app...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f37954aaa890> in <cell line: 19>()
#      20     while True:
# ---> 21         time.sleep(1)
#      22 except KeyboardInterrupt:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/lib/python3.10/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1347             try:
# -> 1348                 h.request(req.get_method(), req.selector, req.data, headers,
#    1349                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /usr/lib/python3.10/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1282         """Send a complete request to the server."""
# -> 1283         self._send_request(method, url, body, headers, encode_chunked)
#    1284
#
# /usr/lib/python3.10/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1328             body = _encode(body, 'body')
# -> 1329         self.endheaders(body, encode_chunked=encode_chunked)
#    1330
#
# /usr/lib/python3.10/http/client.py in endheaders(self, message_body, encode_chunked)
#    1277             raise CannotSendHeader()
# -> 1278         self._send_output(message_body, encode_chunked=encode_chunked)
#    1279
#
# /usr/lib/python3.10/http/client.py in _send_output(self, message_body, encode_chunked)
#    1037         del self._buffer[:]
# -> 1038         self.send(msg)
#    1039
#
# /usr/lib/python3.10/http/client.py in send(self, data)
#     975             if self.auto_open:
# --> 976                 self.connect()
#     977             else:
#
# /usr/lib/python3.10/http/client.py in connect(self)
#     941         sys.audit("http.client.connect", self, self.host, self.port)
# --> 942         self.sock = self._create_connection(
#     943             (self.host,self.port), self.timeout, self.source_address)
#
# /usr/lib/python3.10/socket.py in create_connection(address, timeout, source_address)
#     844         try:
# --> 845             raise err
#     846         finally:
#
# /usr/lib/python3.10/socket.py in create_connection(address, timeout, source_address)
#     832                 sock.bind(source_address)
# --> 833             sock.connect(sa)
#     834             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     517     try:
# --> 518         response = urlopen(request, encoded_data, timeout)
#     519         response_data = response.read().decode("utf-8")
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     518         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519         response = self._open(req, data)
#     520
#
# /usr/lib/python3.10/urllib/request.py in _open(self, req, data)
#     535         protocol = req.type
# --> 536         result = self._call_chain(self.handle_open, protocol, protocol +
#     537                                   '_open', req)
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#
# /usr/lib/python3.10/urllib/request.py in http_open(self, req)
#    1376     def http_open(self, req):
# -> 1377         return self.do_open(http.client.HTTPConnection, req)
#    1378
#
# /usr/lib/python3.10/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1350             except OSError as err: # timeout error
# -> 1351                 raise URLError(err)
#    1352             r = h.getresponse()
#
# URLError: <urlopen error [Errno 111] Connection refused>
#
# During handling of the above exception, another exception occurred:
#
# PyngrokNgrokURLError                      Traceback (most recent call last)
# <ipython-input-10-f37954aaa890> in <cell line: 19>()
#      23     print("Stopping Streamlit app...")
#      24     process.terminate()
# ---> 25     ngrok.disconnect(public_url)
#      26     ngrok.kill()
#
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in disconnect(public_url, pyngrok_config)
#     357
#     358     if public_url not in _current_tunnels:
# --> 359         get_tunnels(pyngrok_config)
#     360
#     361         # One more check, if the given URL is still not in the list of tunnels, it is not active
#
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in get_tunnels(pyngrok_config)
#     395
#     396     _current_tunnels.clear()
# --> 397     for tunnel in api_request(f"{api_url}/api/tunnels", method="GET",
#     398                               timeout=pyngrok_config.request_timeout)["tunnels"]:
#     399         ngrok_tunnel = NgrokTunnel(tunnel, pyngrok_config, api_url)
#
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     541                                     status_code, e.reason, e.headers, response_data)
#     542     except URLError as e:
# --> 543         raise PyngrokNgrokURLError(f"ngrok client exception, URLError: {e.reason}", e.reason)
#     544
#     545
#
# PyngrokNgrokURLError: ngrok client exception, URLError: [Errno 111] Connection refused
